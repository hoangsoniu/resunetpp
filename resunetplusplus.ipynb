# %%
# !python3 /kaggle/input/resunetplusplus/keras/resunetpp/9/resunetpp/process_image.py --input '/kaggle/input/kvasir-seg/' --output '/kaggle/working/new_path' --dataset 'Kvasir-SEG'

# %%
# !python3 /kaggle/input/resunetplusplus/keras/resunetpp/9/resunetpp/run.py --train '/kaggle/working/new_path/Kvasir-SEG/train' --valid '/kaggle/working/new_path/Kvasir-SEG/valid' --files '/kaggle/working/new_path/files'
