# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !python3 /kaggle/input/resunetplusplus/keras/resunetpp/2/resunetpp/process_image.py --input '/kaggle/input/kvasir-seg/' --output '/kaggle/working/new_path' --dataset 'Kvasir-SEG'
# Out:
# /kaggle/input/resunetplusplus/keras/resunetpp/2/resunetpp/process_image.py:8: DeprecationWarning: Please import `rotate` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.interpolation import rotate
# Total Size:  1000
# Training Size:  0.8
# Validation Size:  0.1
# Testing Size:  0.1
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 63.24it/s]
# 100%|███████████████████████████████████████████| 90/90 [00:01<00:00, 60.50it/s]
# 100%|█████████████████████████████████████████| 810/810 [23:43<00:00,  1.76s/it]

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
print(f"Số GPU phát hiện được: {len(gpus)}")
print("Danh sách GPU:")
for gpu in gpus:
    print(gpu)
# Out:
# Số GPU phát hiện được: 2
# Danh sách GPU:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')

# %%
# !python3 /kaggle/input/resunetplusplus/keras/resunetpp/7/resunetpp/run.py --train '/kaggle/working/new_path/Kvasir-SEG/train/' --valid '/kaggle/working/new_path/Kvasir-SEG/valid/' --files '/kaggle/working/files/'
# Out:
# 2025-06-02 12:41:50.189789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748868110.210835    2203 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748868110.217467    2203 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1748868114.624978    2203 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748868114.625674    2203 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Number of devices: 2
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748868158.551127    2227 service.cc:148] XLA service 0x7f6af0288f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748868158.551167    2227 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748868158.551173    2227 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748868161.936910    2227 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-02 12:43:11.240747: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[128,5184,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,256,3,3]{3,2,1,0}, f32[5184,256,2,2]{3,2,1,0}), window={size=2x2 pad=1_1x1_1 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-06-02 12:43:11.621465: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.380902247s
# Trying algorithm eng4{} for conv (f32[128,5184,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,256,3,3]{3,2,1,0}, f32[5184,256,2,2]{3,2,1,0}), window={size=2x2 pad=1_1x1_1 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-06-02 12:43:29.474357: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,80,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,80,256,256]{3,2,1,0}, f32[16,32,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-06-02 12:43:30.200712: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.72644998s
# Trying algorithm eng0{} for conv (f32[32,80,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,80,256,256]{3,2,1,0}, f32[16,32,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1748868230.392083    2227 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  174/1569 ━━━━━━━━━━━━━━━━━━━━ 14:01 603ms/step - dice_coef: 0.4085 - loss: 0.5915 - mean_io_u: 0.4872 - precision: 0.3339 - recall: 0.7246E0000 00:00:1748868350.996662    2228 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748868351.241997    2228 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - dice_coef: 0.4203 - loss: 0.5816 - mean_io_u: 0.5146 - precision: 0.3521 - recall: 0.6974
# Epoch 1: val_loss improved from inf to 0.54609, saving model to /kaggle/working/files/resunetplusplus.h5
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 604s 312ms/step - dice_coef: 0.4203 - loss: 0.5816 - mean_io_u: 0.5146 - precision: 0.3521 - recall: 0.6974 - val_dice_coef: 0.4539 - val_loss: 0.5461 - val_mean_io_u: 0.5191 - val_precision: 0.3490 - val_recall: 0.7064 - learning_rate: 0.0010
# Epoch 2/10
#    1/1569 ━━━━━━━━━━━━━━━━━━━━ 6:11 237ms/step - dice_coef: 0.6946 - loss: 0.3054 - mean_io_u: 0.5988 - precision: 0.7157 - recall: 0.6668/usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
#
# Epoch 2: val_loss did not improve from 0.54609
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - dice_coef: 0.6946 - loss: 0.3054 - mean_io_u: 0.5988 - precision: 0.7157 - recall: 0.6668 - val_dice_coef: 0.4488 - val_loss: 0.5512 - val_mean_io_u: 0.5213 - val_precision: 0.3395 - val_recall: 0.7466 - learning_rate: 0.0010
# Epoch 3/10
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - dice_coef: 0.4456 - loss: 0.5544 - mean_io_u: 0.5278 - precision: 0.3825 - recall: 0.7109
# Epoch 3: val_loss did not improve from 0.54609
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 373s 238ms/step - dice_coef: 0.4456 - loss: 0.5544 - mean_io_u: 0.5278 - precision: 0.3825 - recall: 0.7109 - val_dice_coef: 0.3097 - val_loss: 0.6903 - val_mean_io_u: 0.4037 - val_precision: 0.2437 - val_recall: 0.5330 - learning_rate: 0.0010
# Epoch 4/10
#    1/1569 ━━━━━━━━━━━━━━━━━━━━ 6:08 235ms/step - dice_coef: 0.5836 - loss: 0.4164 - mean_io_u: 0.6042 - precision: 0.4408 - recall: 0.8743
# Epoch 4: val_loss did not improve from 0.54609
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 1s 405us/step - dice_coef: 0.5836 - loss: 0.4164 - mean_io_u: 0.6042 - precision: 0.4408 - recall: 0.8743 - val_dice_coef: 0.3229 - val_loss: 0.6771 - val_mean_io_u: 0.4029 - val_precision: 0.2500 - val_recall: 0.5995 - learning_rate: 0.0010
# Epoch 5/10
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - dice_coef: 0.4622 - loss: 0.5378 - mean_io_u: 0.5332 - precision: 0.4041 - recall: 0.6970
# Epoch 5: val_loss improved from 0.54609 to 0.50210, saving model to /kaggle/working/files/resunetplusplus.h5
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 373s 238ms/step - dice_coef: 0.4622 - loss: 0.5378 - mean_io_u: 0.5332 - precision: 0.4041 - recall: 0.6970 - val_dice_coef: 0.4979 - val_loss: 0.5021 - val_mean_io_u: 0.5567 - val_precision: 0.4060 - val_recall: 0.7150 - learning_rate: 0.0010
# Epoch 6/10
#    1/1569 ━━━━━━━━━━━━━━━━━━━━ 5:56 228ms/step - dice_coef: 0.3613 - loss: 0.6387 - mean_io_u: 0.5022 - precision: 0.3166 - recall: 0.5069
# Epoch 6: val_loss improved from 0.50210 to 0.50178, saving model to /kaggle/working/files/resunetplusplus.h5
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step - dice_coef: 0.3613 - loss: 0.6387 - mean_io_u: 0.5022 - precision: 0.3166 - recall: 0.5069 - val_dice_coef: 0.4982 - val_loss: 0.5018 - val_mean_io_u: 0.5559 - val_precision: 0.4051 - val_recall: 0.7184 - learning_rate: 0.0010
# Epoch 7/10
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - dice_coef: 0.4641 - loss: 0.5359 - mean_io_u: 0.5425 - precision: 0.4151 - recall: 0.6908
# Epoch 7: val_loss improved from 0.50178 to 0.44612, saving model to /kaggle/working/files/resunetplusplus.h5
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 372s 237ms/step - dice_coef: 0.4641 - loss: 0.5359 - mean_io_u: 0.5425 - precision: 0.4151 - recall: 0.6908 - val_dice_coef: 0.5539 - val_loss: 0.4461 - val_mean_io_u: 0.6207 - val_precision: 0.4822 - val_recall: 0.6909 - learning_rate: 0.0010
# Epoch 8/10
#    1/1569 ━━━━━━━━━━━━━━━━━━━━ 6:02 231ms/step - dice_coef: 0.7926 - loss: 0.2074 - mean_io_u: 0.7970 - precision: 0.7418 - recall: 0.8705
# Epoch 8: val_loss did not improve from 0.44612
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 1s 412us/step - dice_coef: 0.7926 - loss: 0.2074 - mean_io_u: 0.7970 - precision: 0.7418 - recall: 0.8705 - val_dice_coef: 0.5534 - val_loss: 0.4466 - val_mean_io_u: 0.6200 - val_precision: 0.4834 - val_recall: 0.6859 - learning_rate: 0.0010
# Epoch 9/10
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - dice_coef: 0.4730 - loss: 0.5270 - mean_io_u: 0.5560 - precision: 0.4381 - recall: 0.6575
# Epoch 9: val_loss did not improve from 0.44612
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 372s 237ms/step - dice_coef: 0.4730 - loss: 0.5270 - mean_io_u: 0.5560 - precision: 0.4381 - recall: 0.6575 - val_dice_coef: 0.4934 - val_loss: 0.5066 - val_mean_io_u: 0.5430 - val_precision: 0.3910 - val_recall: 0.7292 - learning_rate: 0.0010
# Epoch 10/10
#    1/1569 ━━━━━━━━━━━━━━━━━━━━ 5:58 229ms/step - dice_coef: 0.4852 - loss: 0.5148 - mean_io_u: 0.6241 - precision: 0.3543 - recall: 0.9319
# Epoch 10: val_loss did not improve from 0.44612
# 1569/1569 ━━━━━━━━━━━━━━━━━━━━ 1s 416us/step - dice_coef: 0.4852 - loss: 0.5148 - mean_io_u: 0.6241 - precision: 0.3543 - recall: 0.9319 - val_dice_coef: 0.4986 - val_loss: 0.5014 - val_mean_io_u: 0.5472 - val_precision: 0.3979 - val_recall: 0.7283 - learning_rate: 0.0010

# %%
# !python3 /kaggle/input/resunetplusplus/keras/resunetpp/7/resunetpp/infer.py --model '/kaggle/working/files/resunetplusplus.h5' --test '/kaggle/working/new_path/Kvasir-SEG/test' --save '/kaggle/working/files/result'
# Out:
# 2025-06-02 13:17:51.724625: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748870271.746451    2410 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748870271.753061    2410 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1748870276.133249    2410 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748870276.133928    2410 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Test Result:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748870282.231546    2433 service.cc:148] XLA service 0x787370001f00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748870282.231612    2433 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748870282.231625    2433 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748870282.696891    2433 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1748870288.674439    2433 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - dice_coef: 0.4835 - loss: 0.5165 - mean_io_u: 0.5795 - precision: 0.4398 - recall: 0.6644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step0<?, ?it/s]
# [ WARN:0@23.677] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step4.20s/it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step1.79s/it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step1.37it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step1.86it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step2.47it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step3.84it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step4.46it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step5.16it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step5.82it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step6.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step7.24it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step7.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step8.23it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step8.60it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step8.83it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step9.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step9.19it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step9.21it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step9.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step9.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step9.30it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step9.79it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step9.80it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step9.93it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.04it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.04it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.16it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.15it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step0.14it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.10it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.24it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.18it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.09it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.06it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.12it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.14it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step0.17it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.12it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.04it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.10it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.19it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.16it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.16it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.20it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.32it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step0.23it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.20it/s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step0.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step0.16it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 100%|█████████████████████████████████████████| 100/100 [00:14<00:00,  7.10it/s]
# Test image generation complete
